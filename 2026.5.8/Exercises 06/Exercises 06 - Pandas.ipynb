# %% [markdown]
# <table style="float:left">
#     <tr>
#         <td>
#             <img src="images/emlyon.png" style="height:60px; float:left; padding-right:10px; margin-top:5px" />
#             <img src="images/harbin.png" style="height:65px; float:left; padding-right:10px; margin-top:4px" />
#         </td>
#         <td style="padding-bottom:10px;">
#             <h1 style="border-bottom: 1px solid #eeeeee;"> Object Oriented Programming: Python BootCamp </h1>
#             <span style="display:inline-block; margin-top:-15px;">HIT-emlyon BSc Program <br/>
#             April-May 2024, Harbin | © Imène BRIGUI | Saeed VARASTEH
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <div class="alert-info" style="border-bottom: solid 1px lightgray; background-color:#ece4f5;">
#     <img src="images/assignment.png" style="height:60px; float:left; padding-right:10px;" />
#     <span style="font-weight:bold; color:#8966b0">
#         <h4 style="padding-top:25px;"> EXERCISES 06 </h4>
#     </span>
# </div>

# %% [markdown]
# ### Exercises 06 - Pandas
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <div style='color:gray;'>
# PART ONE
# </div>

# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# your code
df = pd.DataFrame(data=data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     str
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 700.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df.iloc[:3]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Select just the 'animal' and 'age' columns from the DataFrame `df`.

# %%
df[["animal", "age"]]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Select the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']`.

# %%
df.loc[ df.index[[3,4,8]] , ['animal', 'age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
mask = df["visits"] >= 3
df[mask]
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
mask = df["age"].isnull()
df[mask]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
mask = (df["animal"] == "cat" ) & (df["age"] < 3)
df[mask]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows the age is between 2 and 4 (inclusive).

# %%
mask = (df["age"] >=2) & (df["age"] <= 4) 
df[mask]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df.loc["f","age"] = 1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
df["visits"].sum()
# Out:
# np.int64(19)

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
df.groupby("animal")["age"].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
df.loc['k'] = ['dog' ,3, 3,'no']
df.drop( index = ['k'], inplace = True)

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
df.groupby("animal").size()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# dtype: int64

# %%
df["animal"].value_counts()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %%
from collections import Counter
Counter(df['animal'])
# Out:
# Counter({'cat': 4, 'dog': 4, 'snake': 2})

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df.sort_values(['age','visits'],ascending = [False, True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
map_p = {"yes" : True , "no" : False} # map : convert all values in a col
df['priority'] = df["priority"].map( map_p)
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df['animal'].replace('snake' , 'python') #replace : only replace one value
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %% [markdown]
# **18.** For each animal type and each number of visits, find the mean age. In other words, each row is an animal, each column is a number of visits and the values are the mean ages (*hint: use a pivot table*).

# %% [markdown]
# <div style='color:gray;'>
# PART TWO
# </div>

# %% [markdown]
# __Pokemon data__
#
# In this exercise, we are using Pokemon dataset.

# %%
df = pd.read_csv('pokemon.csv', index_col=0)
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# #
# 1     45           1      False
# 2     60           1      False
# 3     80           1      False
# 4     65           1      False
# 5     80           1      False

# %% [markdown]
# <h4>Question 1</h4>
#
# Find the most common type-combination of the dataset.
#
# __Reminder:__ You only care about type combinations, i.e. Pokemons that have two types. so for example a combination could be (”Grass”, ”Poison”).

# %%
# your code
df[['Type 1', 'Type 2']].value_counts().head(1)
# Out:
# Type 1  Type 2
# Normal  Flying    23
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).size().idxmax()
# Out:
# ('Normal', 'Flying')

# %% [markdown]
# Let's first create another dataset out of Pokemon.
#
# <h4>Question 2</h4>
#
# Create a new DataFrame out of the original dataset that contains the columns ’Type 1’, ’Type 2’ and the respective counts of these as ’counts’. Named it as `ds`.
#
# The data should look like:
#
# | | Type 1 | Type 2 | counts |
# | --- | --- | --- | --- |
# | 0 | Bug  | Electric | 2 |
# | 1 | Bug  | Fighting | 1 |
# | ... | ...  | ... | ... |
# | 124 | Water  | Steel | 1 |

# %%
# your code
ds = df.groupby(['Type 1', 'Type 2']).size().reset_index(name = 'counts')
ds.head(3)
# Out:
#   Type 1    Type 2  counts
# 0    Bug  Electric       2
# 1    Bug  Fighting       1
# 2    Bug      Fire       2

# %% [markdown]
# <h4>Question 3</h4>
#
# Create a new column called ”types” that is the combination of the columns ”Type 1” and ”Type 2” entries. A possible value in that new column for the row containing the types ”Bug” and ”Electric” could look like this: ”Bug Electric”.

# %%
# your code
ds['types'] = ds['Type 1'] + " " +ds['Type 2']
ds
# Out:
#     Type 1    Type 2  counts          types
# 0      Bug  Electric       2   Bug Electric
# 1      Bug  Fighting       1   Bug Fighting
# 2      Bug      Fire       2       Bug Fire
# 3      Bug    Flying      13     Bug Flying
# 4      Bug     Ghost       1      Bug Ghost
# ..     ...       ...     ...            ...
# 120  Water       Ice       3      Water Ice
# 121  Water    Poison       3   Water Poison
# 122  Water   Psychic       4  Water Psychic
# 123  Water      Rock       4     Water Rock
# 124  Water     Steel       1    Water Steel
#
# [125 rows x 4 columns]

# %% [markdown]
# <h4>Question 4</h4>
#
# Sort the new dataframe in decending order, so the row with the biggest number in the column ”counts” will be the first, the second biggest count will be second and so on.

# %%
# your code
ds= ds.sort_values(['counts'],ascending = False)
ds
# Out:
#       Type 1    Type 2  counts             types
# 73    Normal    Flying      23     Normal Flying
# 56     Grass    Poison      14      Grass Poison
# 3        Bug    Flying      13        Bug Flying
# 7        Bug    Poison      11        Bug Poison
# 119    Water    Ground       9      Water Ground
# ..       ...       ...     ...               ...
# 80    Poison    Dragon       1     Poison Dragon
# 87   Psychic      Fire       1      Psychic Fire
# 86   Psychic  Fighting       1  Psychic Fighting
# 78    Poison       Bug       1        Poison Bug
# 75    Normal    Ground       1     Normal Ground
#
# [125 rows x 4 columns]

# %% [markdown]
# <h4>Question 5</h4>
#
# Create a new dataframe or remove the entries from the data in the previous section so dataset only contains the first 12 entries of the sorted data set (with the counts in ascending order).

# %%
# your code
sorted_df = ds.head(12)
sorted_df
# Out:
#       Type 1    Type 2  counts           types
# 73    Normal    Flying      23   Normal Flying
# 56     Grass    Poison      14    Grass Poison
# 3        Bug    Flying      13      Bug Flying
# 7        Bug    Poison      11      Bug Poison
# 119    Water    Ground       9    Water Ground
# 116    Water    Flying       7    Water Flying
# 5        Bug     Grass       6       Bug Grass
# 35      Fire  Fighting       6   Fire Fighting
# 98      Rock    Ground       6     Rock Ground
# 88   Psychic    Flying       6  Psychic Flying
# 102     Rock     Water       6      Rock Water
# 109    Steel   Psychic       6   Steel Psychic

# %% [markdown]
# <h4>Question 6</h4>
#
# Plot the dataset from the previous section with Horizontal Barplot using the created column ”types”.

# %%
# your code
import seaborn as sns
sns.barplot(data = sorted_df, x='counts', y='types');

# %% [markdown]
# <h4>Question 7</h4>
#
# Using the original Pokemon dataset. make a Scatterplot of their attack and defense.

# %%
# your code
sns.scatterplot( data = df , x = 'Attack' , y = 'Defense');

# %% [markdown]
# <h4>Question 8</h4>
#
# __Scatterplot__
#
# How speed of Pokemon relates to various base factors? (Speed vs Attack & Speed vs Defense) use subploting.
#
# Note: The ”Speed” on both x-axis should be the same.

# %%
# your code
sns.scatterplot( data = df , x = 'Speed' , y = 'Attack')
# Out:
# <Axes: xlabel='Speed', ylabel='Attack'>

# %% [markdown]
# ---
