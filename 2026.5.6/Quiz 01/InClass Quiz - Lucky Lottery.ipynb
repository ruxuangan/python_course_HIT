# %% [markdown]
# <table style="float:left">
#     <tr>
#         <td>
#             <img src="./emlyon.png" style="height:60px; float:left; padding-right:10px; margin-top:5px" />
#             <img src="./harbin.png" style="height:65px; float:left; padding-right:10px; margin-top:4px" />
#         </td>
#         <td style="padding-bottom:10px;">
#             <h1 style="border-bottom: 1px solid #eeeeee;"> Object Oriented Programming: Python BootCamp </h1>
#             <span style="display:inline-block; margin-top:-15px;">HIT-emlyon BSc Program <br/>
#             April-May, Harbin | © Imène BRIGUI | Saeed VARASTEH
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <div class="alert-info" style="border-bottom: solid 1px lightgray; background-color:#d3dbd3;">
#     <img src="./quiz.png" style="height:60px; float:left; padding-right:10px;" />
#     <span style="font-weight:bold; color:#476b47">
#         <h4 style="padding-top:25px;"> QUIZ </h4>
#     </span>
# </div>

# %% [markdown]
# Please enter your name below:

# %%
FullName = "干汝宣"

# %% [markdown]
# ### Lucky Lottery
#
# ---

# %% [markdown]
# #### Objective:
#
# Create a Python program that simulates a simple lottery game!
#
# #### Instructions:
#
# __Step 1: Generate the winning numbers.__
#
# Use the `random` module to generate 6 random winning numbers between 1 and 49. Store the numbers in a suitable data structure.

# %%
# your code
import random
win = []
for i in range(6):
    win.append(random.randint(1,49))
print(win)
# Out:
# [31, 47, 35, 17, 27, 6]

# %% [markdown]
# __Step 2: Prompt the user to enter 6 numbers between 1 and 49.__
#
# Validate the input to ensure that there are no duplicates and that all numbers are within range. Store the numbers in an appropriate data structure.

# %%
# your code

# %% [markdown]
# __Step 3: Compare the numbers.__
#
# Check how many of the user's numbers match the winning numbers and print the appropriate message:
#
# - If all 6 match: "Jackpot! You have won the grand prize!
# - If 5 match: "Great job! You have won a great prize!
# - If 4 match: "Nice! You have won a small prize!
# - If 3 match: "You win a consolation prize!
# - Otherwise, "Better luck next time!

# %%
# your code

# %% [markdown]
# ---
