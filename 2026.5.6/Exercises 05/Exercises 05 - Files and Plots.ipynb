# %% [markdown]
# <table style="float:left">
#     <tr>
#         <td>
#             <img src="images/emlyon.png" style="height:60px; float:left; padding-right:10px; margin-top:5px" />
#             <img src="images/harbin.png" style="height:65px; float:left; padding-right:10px; margin-top:4px" />
#         </td>
#         <td style="padding-bottom:10px;">
#             <h1 style="border-bottom: 1px solid #eeeeee;"> Object Oriented Programming: Python BootCamp </h1>
#             <span style="display:inline-block; margin-top:-15px;">HIT-emlyon BSc Program <br/>
#             April-May, Harbin | © Imène BRIGUI | Saeed VARASTEH
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <div class="alert-info" style="border-bottom: solid 1px lightgray; background-color:#ece4f5;">
#     <img src="images/assignment.png" style="height:60px; float:left; padding-right:10px;" />
#     <span style="font-weight:bold; color:#8966b0">
#         <h4 style="padding-top:25px;"> EXERCISES 05 </h4>
#     </span>
# </div>

# %% [markdown]
# ### Exercises 05 - Files and Plots
#
# ---

# %% [markdown]
# <div style='color:gray;'>
# PART ONE
# </div>

# %% [markdown]
# __Text Files__
#
# You are given a __.txt__ file called "poem.txt".
#
# Write a script that reads in the file and prints the poem.

# %%
# your code
my_file = open(file = "poem.txt", mode = "r")
print(my_file.read())
my_file.close()
# Out:
# In the man's arena
# You can't ignore a woman.
# The contribution in building the nation is same,
# Instead of getting appreciation, she is put on blame.
# Gender equality is today's demand,
# Encourage this, it will expand.
# The worth of the woman should always be praised,
# The issue of equality is put on ablaze.
# It is a man's best quality,

# %% [markdown]
# The following sentence is missing from the end of the poem:
#
# __If he believes in equality.__
#
# Add it to the end of the file and save it. Check your file to make sure you did it correctly.

# %%
# your code
my_file = open(file = "poem.txt", mode = "a")
my_file.write("\nIf he believes in equality.")
my_file.close()
my_file = open(file = "poem.txt", mode = "r")
print(my_file.read())
# Out:
# In the man's arena
# You can't ignore a woman.
# The contribution in building the nation is same,
# Instead of getting appreciation, she is put on blame.
# Gender equality is today's demand,
# Encourage this, it will expand.
# The worth of the woman should always be praised,
# The issue of equality is put on ablaze.
# It is a man's best quality,
# If he believes in equality.

# %% [markdown]
# __Log Files__
#
# You are given a .txt file called __mbox-short.txt__.
#
# Write a code that reads the file and looks for lines containing 'http'. Your task is to extract the URLs from these lines and print them out.

# %%
myfile = open("mbox-short.txt", "r")
out = myfile.readlines()
myfile.close()

# your code
for line in out:
    if line[:4] == "http":
        print(line)
# Out:
# http://jira.sakaiproject.org/jira/browse/SAK-12488
#
# http://jira.sakaiproject.org/jira/browse/SAK-12484
#
# http://bugs.sakaiproject.org/jira/browse/SAK-12596
#
# http://bugs.sakaiproject.org/jira/browse/SAK-12595
#
# http://bugs.sakaiproject.org/jira/browse/SAK-12592
#
# http://bugs.sakaiproject.org/jira/browse/SAK-12175
#
# http://jira.sakaiproject.org/jira/browse/SAK-12504
#
# http://bugs.sakaiproject.org/jira/browse/SAK-11458

# %% [markdown]
# <div style='color:gray;'>
# PART TWO
# </div>

# %% [markdown]
# __First Plot__
#
# Create a list of values from -5 to 5.
#
# Your task is to plot each value against its own squared value.
#
# (this should result in an edgy version of the known quadratic parabola).

# %%
# your code
x = list(range(-5,6))
y = [a**2 for a in x]
import matplotlib.pyplot as plt
plt.plot(x,y);

# %% [markdown]
# __Spiral__
#
# You are given a __.txt__ file named __spiral_data.txt__.
#
# Each line of this file contains the __x__ and __y__ coordinates of a point in a 2D plane. Read this file, save the x and y values in an appropriate data structure and then plot __x values__ versus the __y values__ in a scatter plot.

# %%
# your code
file = open (file ="spiral_data.txt", mode = "r" )
data = file.readlines()
file.close()
x = []
y = []
for v in data:
    vx, vy = v.split(",")
    vx = float(vx)
    vy = float(vy)
    x.append(vx)
    y.append(vy)
import matplotlib.pyplot as plt
plt.scatter(x,y);

# %% [markdown]
# ---
